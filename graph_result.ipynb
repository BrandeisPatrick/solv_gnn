# %%
import pandas as pd 
import numpy as np

# %%
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the file
with open('predictions.txt', 'r') as file:
    data = file.readlines()

# Extract the x and y values from the data
pred = []
true = []
for line in data[1:]:
    values = line.strip().split(',')
    pred.append(float(values[0]))
    true.append(float(values[1]))

    df = pd.DataFrame({'pred': pred, 'true': true})
    # Calculate MSE and R2 

mse = mean_squared_error(true, pred)

# Set up the scatterplot
plt.xlim(0, 300)  # Set x-axis limits
plt.ylim(0, 300)
sns.scatterplot(x='true', y='pred', data=df)
sns.kdeplot(x='true', y='pred', data=df, cmap='rainbow', shade=True)
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot')

# Display MSE on the graph
plt.text(0.1, 0.9, f'MSE: {mse:.2f}', transform=plt.gca().transAxes)

plt.show()

# # Calculate MSE and R2 
# mse = mean_squared_error(x, y)
# r2 = r2_score(x, y)

# # Set up the scatterplot
# plt.xlim(0, 300)  # Set x-axis limits
# plt.ylim(0, 300)
# sns.scatterplot(x=y, y=x)
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('Parity Plot')

# # Display MSE and R2 on the graph
# plt.text(0.1, 0.9, f'MSE: {mse:.2f}', transform=plt.gca().transAxes)
# plt.text(0.1, 0.85, f'R2: {r2:.2f}', transform=plt.gca().transAxes)

# plt.show()
